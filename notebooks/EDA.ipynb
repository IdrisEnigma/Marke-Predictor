# %% [markdown]
# Work Package: Ultra/Alpha Filtration –
# Baseline Test
# Owner: Data Scientist
# Reviewer: Steffan Barreau
# Purpose:
# Test and benchmark the Ultra/Alpha Filtration process to understand:
# 1. How many large-cap companies (e.g. S&P 500) we’re actually pulling in, and
# 2. How many get filtered out by the base financial rules.
# 1. Objective
# Build a simple baseline version of the filtration engine.
# It doesn’t need to be automated or production-ready — the goal is just to see how much
# of the universe passes or fails the core financial filters.

# %%
import yfinance as yf
import pandas as pd

# -----------------------------
# Step 1 — Load list of large-cap companies (S&P 500)
# -----------------------------
sp500_url = "https://raw.githubusercontent.com/datasets/s-and-p-500-companies/master/data/constituents.csv"
sp500_df = pd.read_csv(sp500_url)

tickers = sp500_df["Symbol"].tolist()
print(f"Loaded {len(tickers)} tickers")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import yfinance as yf
#       2 import pandas as pd
#       4 # -----------------------------
#       5 # Step 1 — Load list of large-cap companies (S&P 500)
#       6 # -----------------------------
#
# ModuleNotFoundError: No module named 'yfinance'

# %%
# !pip install yfinance --quiet
# Out:
# ^C
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\IdrisEl-Feghi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
